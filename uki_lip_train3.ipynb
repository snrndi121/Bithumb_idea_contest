# %% [markdown]
# <a href="https://colab.research.google.com/github/ukiKwon/Bithumb_idea_contest/blob/master/uki_lip_train3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 구글 드라이브 마운트
from google.colab import drive
drive.mount('/content/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
# 기본 라이브러리
# %tensorflow_version 1.x
#%tensorflow_version 2.x
# 1. 텐서플로우
#!pip install tensorflow==1.2

# 2. 파이썬 오픈 cv2
# !pip install opencv-python h5py

# 3. 케라스 재설치 
#!pip install q keras==2.0.3
#!pip uninstall keras
#requirements.txt = keras-frcnn 에서 기입한 개발 환경 목록
# !pip install -r /content/gdrive/'My Drive'/keras-frcnn/requirements.txt
# Out:
# TensorFlow 1.x selected.
# ...
#      |████████████████████████████████| 204kB 3.5MB/s
# ...
#   Created wheel for Keras: filename=Keras-2.0.3-cp36-none-any.whl size=232962 sha256=ede7f85be5159f5d2a5c7d0e51894043395ecf4eda56c032538a570333b52d97
#   Stored in directory: /root/.cache/pip/wheels/a6/fb/de/faea9e49d563a35f198c6dede7f9260074b5beb8f9bffaaaa1
# Successfully built Keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.3 which is incompatible.
# ...
#   Found existing installation: Keras 2.3.1
#     Uninstalling Keras-2.3.1:
#       Successfully uninstalled Keras-2.3.1
# ...

# %%
# 폴더 탐색되는 지 확인
#!ls /content/gdrive/'My Drive'/keras-frcnn/

#  파일 기본 경로 변경
#!cd /content/gdrive/'My Drive'/keras-frcnn/
# %cd /content/gdrive/'My Drive'/keras-frcnn/


# 현재 경로 확인
#!ls
# Out:
# /content/gdrive/My Drive/keras-frcnn

# %%
#버전1
#!python /content/gdrive/'My Drive'/keras-frcnn/train_frcnn.py --path /content/gdrive/'My Drive'/keras-frcnn/ --num_epochs 20  --output_weight_path ./lip_weight_train1.hdf5

#버전2
#!python ./train_frcnn.py --path ./ --num_epochs 1 --config_filename ./lips_config.pickle --output_weight_path ./lip_weight_train.hdf5
# !python ./train_frcnn.py --path ./ --num_epochs 1 --config_filename ./lips_config.pickle --output_weight_path ./lip_weight_train2.hdf5 --input_weight_path ./lip_weight_train1.hdf5
# Out:
# Using TensorFlow backend.
# Parsing annotation files
# Training images per class:
# {'bg': 0,
#  'shape_a': 375,
#  'shape_e': 401,
#  'shape_eo': 354,
#  'shape_i': 569,
#  'shape_none': 419,
#  'shape_o': 526,
#  'shape_ui': 97}
# Num classes (including bg) = 8
# Config has been written to ./lips_config.pickle, and can be loaded when testing to ensure correct results
# Num train samples 2188
# Num val samples 547
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# ...

# %%
# 테스트 시행
# !python ./test_frcnn.py --path ./images --config_filename ./lips_config.pickle
# Out:
# Using TensorFlow backend.
# {0: 'shape_none', 1: 'shape_eo', 2: 'shape_e', 3: 'shape_a', 4: 'shape_ui', 5: 'shape_i', 6: 'shape_o', 7: 'bg'}
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:47: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:351: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3176: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3043: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...

# %%
# colab 내 경로 확인 테스트
#!ls /content/gdrive/'My Drive'/keras-frcnn/

#!ls /content/gdrive/My Drive/keras-frcnn/

#!ls /content/gdrive/My\ Drive/keras-frcnn/
